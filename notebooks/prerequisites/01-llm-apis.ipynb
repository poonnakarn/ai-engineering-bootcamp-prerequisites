# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### OpenAI Client

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "print 10 random words?"}],
)

print(response.choices[0].message.content)
# Out:
# quiver mango fortress aurora comet drizzle kettle labyrinth velvet atlas

# %% [markdown]
# It took 5-7 sec because of the reasoning tokens were used.

# %%
response.usage # View usage
# Out:
# CompletionUsage(completion_tokens=469, prompt_tokens=22, total_tokens=491, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=448, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}],
    reasoning_effort="minimal"
)

print(response.choices[0].message.content)
# Out:
# Sure! Here are 10 random words:
#
# 1. cascade
# 2. ember
# 3. quartz
# 4. ripple
# 5. velvet
# 6. lantern
# 7. mango
# 8. prism
# 9. drift
# 10. sunflower

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=57, prompt_tokens=24, total_tokens=81, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}],
    reasoning_effort="low"
)

print(response.choices[0].message.content)
# Out:
# 1) galaxy
# 2) ember
# 3) ripple
# 4) kettle
# 5) prism
# 6) drone
# 7) velvet
# 8) orchards
# 9) lantern
# 10) quill

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=178, prompt_tokens=24, total_tokens=202, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=128, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %% [markdown]
# ### Google Gemini Client

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant.",
            "can you print 15 random words?"],
)

print(response.text)
# Out:
# Here are 15 random words:
#
# 1.  Table
# 2.  Sky
# 3.  Music
# 4.  Quiet
# 5.  Cloud
# 6.  Happy
# 7.  River
# 8.  Green
# 9.  Stone
# 10. Think
# 11. Dream
# 12. Road
# 13. Bright
# 14. Forest
# 15. Wave

# %% [markdown]
# ### Groq Client

# %%
from groq import Groq

groq_client = Groq(
    api_key=os.getenv("GROQ_API_KEY"),
)

chat_completion = groq_client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 20 random words?"}],
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are 20 random words:
#
# 1. Space
# 2. Helicopter
# 3. Coffee
# 4. Dragon
# 5. Guitar
# 6. Banana
# 7. Snowflake
# 8. Perfume
# 9. Llama
# 10. Starfish
# 11. Bicycle
# 12. Cake
# 13. Pineapple
# 14. Harmonica
# 15. Fountain
# 16. Kitten
# 17. Parachute
# 18. Peacock
# 19. Microscope
# 20. Tornado
